# %%
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ekg = scipy.datasets.electrocardiogram();
# Out:
# Downloading file 'ecg.dat' from 'https://raw.githubusercontent.com/scipy/dataset-ecg/main/ecg.dat' to 'C:\Users\Danie\AppData\Local\scipy-data\scipy-data\Cache'.

# %%
plt.plot(ekg);

# %% [markdown]
# This is the whole 5 minutes of data squeezed into one plot. The ekg waves are all mashed together due to the short x axis length. Lets plot a smaller portion of the ekg:

# %%
plt.plot(ekg[11000:12000]);
